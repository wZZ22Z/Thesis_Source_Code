# %% [markdown]
# <a href="https://colab.research.google.com/github/wZZ22Z/Thesis_Source_Code/blob/main/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87%E4%BB%A3%E7%A0%81_OPT2_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 毕业论文代码
#
# Smooth+AWQ
# ## OPT-2.7b

# %% [markdown]
# ## 1.安装事先需要准备的包

# %% [markdown]
# 安装autoAWQ、datasets和评估工具

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 9.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 13.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# ## 2.实现smooth操作

# %%
import torch
from transformers.models.opt.modeling_opt import (
    OPTAttention,
    OPTDecoderLayer,
    OPTForCausalLM,
)
from transformers import GPT2Tokenizer
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn

from transformers.models.opt.modeling_opt import OPTDecoderLayer
from transformers.models.bloom.modeling_bloom import BloomBlock
from transformers.models.llama.modeling_llama import LlamaDecoderLayer, LlamaRMSNorm
from transformers.models.mistral.modeling_mistral import (
    MistralDecoderLayer,
    MistralRMSNorm,
)
from transformers.models.mixtral.modeling_mixtral import (
    MixtralDecoderLayer,
    MixtralRMSNorm,
)
from transformers.models.falcon.modeling_falcon import FalconDecoderLayer


@torch.no_grad()
def smooth_ln_fcs(ln, fcs, act_scales, alpha=0.5):
    if not isinstance(fcs, list):
        fcs = [fcs]
    assert isinstance(ln, nn.LayerNorm)
    for fc in fcs:
        assert isinstance(fc, nn.Linear)
        assert ln.weight.numel() == fc.in_features == act_scales.numel()

    device, dtype = fcs[0].weight.device, fcs[0].weight.dtype
    act_scales = act_scales.to(device=device, dtype=dtype)
    weight_scales = torch.cat(
        [fc.weight.abs().max(dim=0, keepdim=True)[0] for fc in fcs], dim=0
    )
    weight_scales = weight_scales.max(dim=0)[0].clamp(min=1e-5)

    scales = (
        (act_scales.pow(alpha) / weight_scales.pow(1 - alpha))
        .clamp(min=1e-5)
        .to(device)
        .to(dtype)
    )

    ln.weight.div_(scales)
    ln.bias.div_(scales)

    for fc in fcs:
        fc.weight.mul_(scales.view(1, -1))


@torch.no_grad()
def smooth_ln_fcs_llama_like(ln, fcs, act_scales, alpha=0.5):
    if not isinstance(fcs, list):
        fcs = [fcs]
    assert isinstance(ln, (LlamaRMSNorm, MistralRMSNorm, MixtralRMSNorm))
    for fc in fcs:
        assert isinstance(fc, nn.Linear)
        assert ln.weight.numel() == fc.in_features == act_scales.numel()
    device, dtype = fcs[0].weight.device, fcs[0].weight.dtype
    act_scales = act_scales.to(device=device, dtype=dtype)
    weight_scales = torch.cat(
        [fc.weight.abs().max(dim=0, keepdim=True)[0] for fc in fcs], dim=0
    )
    weight_scales = weight_scales.max(dim=0)[0].clamp(min=1e-5)
    scales = (
        (act_scales.pow(alpha) / weight_scales.pow(1 - alpha))
        .clamp(min=1e-5)
        .to(device)
        .to(dtype)
    )

    ln.weight.div_(scales)
    for fc in fcs:
        fc.weight.mul_(scales.view(1, -1))


@torch.no_grad()
def smooth_lm(model, scales, alpha=0.5):
    for name, module in model.named_modules():
        if isinstance(module, OPTDecoderLayer):
            attn_ln = module.self_attn_layer_norm
            qkv = [
                module.self_attn.q_proj,
                module.self_attn.k_proj,
                module.self_attn.v_proj,
            ]
            qkv_input_scales = scales[name + ".self_attn.q_proj"]
            smooth_ln_fcs(attn_ln, qkv, qkv_input_scales, alpha)

            ffn_ln = module.final_layer_norm
            fc1 = module.fc1
            fc1_input_scales = scales[name + ".fc1"]
            smooth_ln_fcs(ffn_ln, fc1, fc1_input_scales, alpha)
        elif isinstance(module, (LlamaDecoderLayer, MistralDecoderLayer)):
            attn_ln = module.input_layernorm  # attention forward norm
            qkv = [
                module.self_attn.q_proj,
                module.self_attn.k_proj,
                module.self_attn.v_proj,
            ]

            qkv_input_scales = scales[name + ".self_attn.q_proj"]
            smooth_ln_fcs_llama_like(attn_ln, qkv, qkv_input_scales, alpha)

            ffn_ln = module.post_attention_layernorm  # feed forward norm
            fcs = [module.mlp.gate_proj, module.mlp.up_proj]
            fcs_input_scales = scales[name + ".mlp.gate_proj"]

            smooth_ln_fcs_llama_like(ffn_ln, fcs, fcs_input_scales, alpha)
        elif isinstance(module, MixtralDecoderLayer):
            attn_ln = module.input_layernorm  # attention forward norm
            qkv = [
                module.self_attn.q_proj,
                module.self_attn.k_proj,
                module.self_attn.v_proj,
            ]

            qkv_input_scales = scales[name + ".self_attn.q_proj"]
            smooth_ln_fcs_llama_like(attn_ln, qkv, qkv_input_scales, alpha)

            ffn_ln = module.post_attention_layernorm  # feed forward norm
            fcs = [module.block_sparse_moe.gate]
            for expert in module.block_sparse_moe.experts:
                fcs.append(expert.w1)
                fcs.append(expert.w3)
            fcs_input_scales = scales[name + ".block_sparse_moe.gate"]

            smooth_ln_fcs_llama_like(ffn_ln, fcs, fcs_input_scales, alpha)

# %% [markdown]
# ## 3.实现任务评估器

# %% [markdown]
# ### LAMBADA 任务简介
#
# #### 概述
# LAMBADA（Language Modeling Broadened to Account for Discourse Aspects）是一种评估语言模型理解长程依赖能力的任务。该任务要求模型根据给定的上下文预测目标句子中的最后一个单词。
#
# #### 任务特点
# - **长程依赖**：需要模型理解整个段落的语义信息
# - **上下文敏感**：正确预测通常依赖于多个句子的信息
# - **自然语言理解**：测试模型对复杂语言结构的理解能力
#
# #### 数据格式
# ```text
# Context: "一段包含多个句子的上下文"
# Target: "需要预测的目标词"
# ```
#
# #### 示例
# ```text
# Context: "小明去了商店。他买了一些水果，包括苹果、香蕉和橙子。当他回到家时，他发现忘记买了最重要的东西——"
# Target: "草莓"
# ```
#
# #### 评价指标
# - **准确率**：正确预测目标词的比例
# $$
# Accuracy = \frac{\text{Number of correct predictions}}{\text{Total number of predictions}}
# $$
#
# #### 任务意义
# - 衡量模型对上下文的理解能力
# - 测试模型处理长文本的能力
# - 评估模型在实际应用场景中的表现

# %% [markdown]
# #### 具体代码实现：

# %%
from torch.amp import autocast

class Evaluator_lambada:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

        # Tokenize the dataset
        def tokenize_function(examples):
            return self.tokenizer(examples["text"])

        self.dataset = self.dataset.map(tokenize_function, batched=True)
        self.dataset.set_format(type="torch", columns=["input_ids"])

    @torch.no_grad()  # 需要放在函数定义外部
    def evaluate(self, model):
        model.to(self.device)  # 确保模型在 GPU
        model.eval()

        total, hit = 0, 0
        for batch in self.dataset:
            input_ids = batch["input_ids"].to(self.device)  # 确保数据在 GPU
            input_ids = input_ids.unsqueeze(0)  # 添加 batch 维度

            label = input_ids[:, -1]  # 目标 token

            # 使用自动混合精度计算
            with autocast('cuda'):  # 使用新的方式指定设备
                outputs = model(input_ids)  # 进行推理
                last_token_logits = outputs.logits[:, -2, :]  # 获取倒数第二个 token 的 logits
                pred = last_token_logits.argmax(dim=-1)  # 预测 token

            total += label.size(0)
            hit += (pred == label).sum().item()

        acc = hit / total
        return acc

# %%
from datasets import load_dataset

tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
dataset_lambada = load_dataset("lambada", split="validation[:1000]")
evaluator_lambada = Evaluator_lambada(dataset_lambada, tokenizer, "cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/7.32k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/281M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2662 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5153 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4869 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# ### HellaSwag 任务简介
#
# #### 概述
# HellaSwag（Harder Endings, Longer contexts, and Logical Assumptions in Situations With Antecedent Graphs）是一种评估模型常识推理和情境理解能力的任务。该任务要求模型根据给定的情境选择最可能的后续事件。
#
# #### 任务特点
# - **常识推理**：需要模型具备日常生活的常识性知识
# - **情境理解**：正确答案依赖于对上下文情境的深入理解
# - **多选项选择**：从多个候选答案中选择最合理的后续
# - **长文本处理**：涉及较长的上下文描述
#
# #### 数据格式
# ```text
# Context: "一段描述情境的上下文"
# Candidates: ["选项1", "选项2", "选项3", "选项4"]
# Answer: "正确答案的索引或内容"
# ```
#
# #### 示例
# ```text
# Context: "一个人在切菜时，发现刀变得越来越钝。接下来他可能会做什么？"
# Candidates: ["继续切菜", "停下来磨刀", "换一把刀", "直接用手撕"]
# Answer: "停下来磨刀"
# ```
#
# #### 评价指标
# - **准确率**：正确选择后续事件的比例
# $$
# Accuracy = \frac{\text{Number of correct predictions}}{\text{Total number of predictions}}
# $$
#
# #### 任务意义
# - 衡量模型的常识推理能力
# - 测试模型对真实世界情境的理解水平
# - 评估模型生成合理预测的能力
# - 在对话系统、故事生成等应用场景中具有重要价值
#
# HellaSwag任务通过设计具有挑战性的情境推理问题，能够有效测试语言模型是否真正理解了人类行为和常识逻辑，而不仅仅是依赖表面的语言模式匹配。

# %% [markdown]
# ### 代码实现：

# %%
from torch.amp import autocast

class Evaluator_HellaSwag:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            ctx_a = sample["ctx_a"]  # 获取第一部分上下文
            ctx_b = sample["ctx_b"]  # 获取第二部分上下文
            endings = sample["endings"]  # 获取四个结尾选项
            correct_label = sample["label"]  # 正确答案的标签，如 '3' 对应选项 'D'

            # Tokenize the context and all endings
            inputs = [self.tokenizer(ctx_a + " " + ctx_b + " " + ending, return_tensors="pt").to(self.device) for ending in endings]

            # 计算每个选项的 logits
            logits = []
            with autocast(device_type='cuda'):  # 开启混合精度
                for input_ids in inputs:
                    output = model(**input_ids)
                    logits.append(output.logits[:, -1, :].max().item())  # 获取每个选项的最大分数

            # 根据最高分数选择答案
            pred = logits.index(max(logits))  # 选择分数最高的选项的索引

            # 将预测结果与正确标签对比
            hit += (pred == int(correct_label))  # 判断预测是否正确
            total += 1

        acc = hit / total
        return acc

# %%
from datasets import load_dataset


# 加载 HellaSwag 数据集
dataset_hellaswag = load_dataset("hellaswag", split="validation[:1000]",trust_remote_code=True)

tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
# 创建评估器
evaluator_hellaswag = Evaluator_HellaSwag(dataset_hellaswag, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/6.84k [00:00<?, ?B/s]
# hellaswag.py:   0%|          | 0.00/4.36k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/2.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/47.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/39905 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10003 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10042 [00:00<?, ? examples/s]

# %% [markdown]
# ### PIQA 任务简介
#
# #### 概述
# PIQA（Physical Interaction QA）是一种评估模型对物理常识和实际交互理解能力的任务。该任务要求模型根据问题选择最符合物理常识或实际生活逻辑的答案。
#
# #### 任务特点
# - **物理常识**：需要模型掌握与物理世界交互的基本知识
# - **实用性**：侧重于日常生活中实际问题的解决能力
# - **多选项选择**：从两个候选答案中选择最合理的解决方案
# - **人类行为理解**：涉及对人类行为及其后果的推理
#
# #### 数据格式
# ```text
# Question: "描述一个问题的情境"
# Candidates: ["选项1", "选项2"]
# Answer: "正确答案的索引或内容"
# ```
#
# #### 示例
# ```text
# Question: "如何让一杯热水快速冷却？"
# Candidates: ["将杯子放入冰箱", "用吹风机对着杯子吹"]
# Answer: "将杯子放入冰箱"
# ```
#
# #### 评价指标
# - **准确率**：正确选择解决方案的比例
# $$
# Accuracy = \frac{\text{Number of correct predictions}}{\text{Total number of predictions}}
# $$
#
# #### 任务意义
# - 衡量模型对物理常识的理解能力
# - 测试模型在实际生活场景中的推理水平
# - 评估模型生成合理解决方案的能力
# - 在智能家居、机器人交互等应用场景中具有重要价值

# %%
from torch.amp import autocast

class Evaluator_PIQA:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            question = sample["goal"]
            option1 = sample["sol1"]
            option2 = sample["sol2"]
            correct_label = sample["label"]  # 0 or 1

            # 计算两个选项的得分
            inputs1 = self.tokenizer(question + " " + option1, return_tensors="pt").to(self.device)
            inputs2 = self.tokenizer(question + " " + option2, return_tensors="pt").to(self.device)

            # 使用混合精度进行计算
            with autocast("cuda"):
                logits1 = model(**inputs1).logits[:, -1, :].to(torch.float32)  # 转换为 float32
                logits2 = model(**inputs2).logits[:, -1, :].to(torch.float32)

            # 获取每个选项的最大 logit
            score1 = torch.max(logits1).item()  # 选出最高的 logit
            score2 = torch.max(logits2).item()

            # 根据分数选择答案
            pred = 0 if score1 > score2 else 1
            hit += int(pred == correct_label)
            total += 1

        # 计算准确率
        acc = hit / total
        return acc

# %%
import torch
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM


dataset_piqa = load_dataset("piqa", split="validation[:1000]",trust_remote_code=True)
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_piqa = Evaluator_PIQA(dataset_piqa, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/8.41k [00:00<?, ?B/s]
# piqa.py:   0%|          | 0.00/5.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/815k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16113 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3084 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1838 [00:00<?, ? examples/s]

# %% [markdown]
# ### WSC

# %%
from torch.amp import autocast

class Evaluator_WSC:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            sentence = sample["text"]
            options = sample["options"]
            correct_label = sample["label"]  # 0 或 1

            scores = []
            for option in options:
                input_text = sentence.replace("___", option)  # 替换空白处
                inputs = self.tokenizer(input_text, return_tensors="pt").to(self.device)

                with autocast("cuda"):
                    logits = model(**inputs).logits[:, -1, :].to(torch.float32)

                scores.append(logits.max().item())

            pred = scores.index(max(scores))  # 获取最大得分的索引

            hit += (pred == correct_label)
            total += 1

        acc = hit / total
        return acc

# %%
import torch
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_wsc = load_dataset("winograd_wsc", "wsc285", split="test[:1000]",trust_remote_code=True)  # 或 "wsc273"
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_wsc = Evaluator_WSC(dataset_wsc, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/8.61k [00:00<?, ?B/s]
# winograd_wsc.py:   0%|          | 0.00/5.42k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/113k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/285 [00:00<?, ? examples/s]

# %% [markdown]
# ### ARC

# %%
from torch.amp import autocast

class Evaluator_ARC:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            question = sample["question"]
            choices = sample["choices"]["text"]  # 获取所有选项的文本
            correct_label = sample["answerKey"]  # 正确答案的标签，例如 'D'

            # Tokenize the question and all choices
            inputs = [self.tokenizer(question + " " + choice, return_tensors="pt").to(self.device) for choice in choices]

            # 使用每个选项的 logits 进行预测
            logits = []
            for input_ids in inputs:
                with autocast(device_type='cuda'):  # 使用新的方式指定设备
                    output = model(**input_ids)
                    logits.append(output.logits[:, -1, :].max().item())  # 获取每个选项的最大分数

            # 根据最高分数选择答案
            pred_index = logits.index(max(logits))  # 获取分数最高的选项的索引
            pred = chr(ord('A') + pred_index)  # 将索引转换为字母标签（例如 0 -> 'A', 1 -> 'B', ...）

            # 将预测结果与正确标签对比
            hit += (pred == correct_label)  # 判断预测是否正确
            total += 1

        acc = hit / total
        return acc

# %%
import torch
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_arc = load_dataset("ai2_arc", "ARC-Challenge", split="validation[:1000]")  # 或 "ARC-Easy"
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_arc = Evaluator_ARC(dataset_arc, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/9.00k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# train-00000-of-00001.parquet:   0%|          | 0.00/190k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# test-00000-of-00001.parquet:   0%|          | 0.00/204k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# validation-00000-of-00001.parquet:   0%|          | 0.00/55.7k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1119 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1172 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/299 [00:00<?, ? examples/s]

# %% [markdown]
# ### BooIQ

# %%
from torch.amp import autocast

class Evaluator_BoolQ:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            question = sample["question"]
            passage = sample["passage"]
            correct_label = sample["answer"]  # 0 (False) 或 1 (True)

            input_text = question + " " + passage
            inputs = self.tokenizer(input_text, return_tensors="pt").to(self.device)

            with autocast("cuda"):
                logits = model(**inputs).logits[:, -1, :].to(torch.float32)

            pred = 1 if logits.max().item() > 0 else 0
            hit += int(pred == correct_label)
            total += 1

        acc = hit / total
        return acc

# %%
import torch
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_boolq = load_dataset("boolq", split="validation[:1000]")
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_boolq = Evaluator_BoolQ(dataset_boolq, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/6.57k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/3.69M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9427 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3270 [00:00<?, ? examples/s]

# %% [markdown]
# ### RACE

# %%
from torch.amp import autocast
class Evaluator_RACE:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            article = sample["article"]  # 获取文章内容
            question = sample["question"]  # 获取问题
            choices = sample["options"]  # 获取所有选项
            correct_label = sample["answer"]  # 获取正确答案的标签（例如 'C'）

            # Tokenize the article, question, and all choices
            inputs = [self.tokenizer(article + " " + question + " " + choice, return_tensors="pt").to(self.device) for choice in choices]

            # 使用每个选项的 logits 进行预测
            logits = []
            for input_ids in inputs:
              with autocast(device_type='cuda'):  # 使用新的方式指定设备
                output = model(**input_ids)
                logits.append(output.logits[:, -1, :].max().item())  # 获取每个选项的最大分数

            # 根据最高分数选择答案
            pred_index = logits.index(max(logits))  # 获取分数最高的选项的索引
            pred = chr(ord('A') + pred_index)  # 将索引转换为字母标签（例如 0 -> 'A', 1 -> 'B', ...）

            # 将预测结果与正确标签对比
            hit += (pred == correct_label)  # 判断预测是否正确
            total += 1

        acc = hit / total
        return acc

# %%
import torch
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_race = load_dataset("race", "middle", split="validation[:1000]")  # 可选择 "high" 或 "middle"
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_race = Evaluator_RACE(dataset_race, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/11.0k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/405k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/6.97M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/407k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/1436 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/25421 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1436 [00:00<?, ? examples/s]

# %% [markdown]
# ### WinoGrande

# %%
from torch.amp import autocast

class Evaluator_WinoGrande:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            sentence = sample["sentence"]  # 获取句子
            option1 = sample["option1"]  # 选项1
            option2 = sample["option2"]  # 选项2
            correct_label = sample["answer"]  # 正确答案，通常是 '1' 或 '2'

            # 生成两个可能的输入文本
            inputs = [
                self.tokenizer(sentence.replace("_", option1), return_tensors="pt").to(self.device),
                self.tokenizer(sentence.replace("_", option2), return_tensors="pt").to(self.device)
            ]

            # 计算两个选项的 logits
            logits = []
            with autocast(device_type='cuda'):  # 开启混合精度
                for input_ids in inputs:
                    output = model(**input_ids)
                    logits.append(output.logits[:, -1, :].max().item())  # 获取最高分数

            # 选择分数最高的选项
            pred = logits.index(max(logits)) + 1  # 索引从0开始，因此需要 +1

            # 计算正确率
            hit += (pred == int(correct_label))
            total += 1

        acc = hit / total
        return acc

# %%
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

# 加载 WinoGrande 数据集
dataset_winogrande = load_dataset("winogrande", "winogrande_xl", split="validation[:1000]",trust_remote_code=True)  # 选择 winogrande_xl 子集

# 加载 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")

# 创建评估器
evaluator_winogrande = Evaluator_WinoGrande(dataset_winogrande, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/9.97k [00:00<?, ?B/s]
# winogrande.py:   0%|          | 0.00/5.65k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/40398 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1767 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1267 [00:00<?, ? examples/s]

# %% [markdown]
# ### OpenBookQA

# %%
from torch.amp import autocast

class Evaluator_OpenBookQA:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device
        self.label_map = {"A": 0, "B": 1, "C": 2, "D": 3}  # 选项标签映射

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            question = sample["question_stem"]  # 获取问题
            options = sample["choices"]["text"]  # 获取 4 个选项
            correct_label = self.label_map[sample["answerKey"]]  # 解析正确答案索引

            # 构造 4 个输入（问题 + 选项）
            inputs = [
                self.tokenizer(question + " " + option, return_tensors="pt").to(self.device)
                for option in options
            ]

            # 计算 logits
            logits = []
            with autocast(device_type='cuda'):  # 开启混合精度推理
                for input_ids in inputs:
                    output = model(**input_ids)
                    logits.append(output.logits[:, -1, :].max().item())  # 获取最大 logits 值

            # 选择最高分的答案
            pred = logits.index(max(logits))

            # 计算准确率
            hit += (pred == correct_label)
            total += 1

        acc = hit / total
        return acc

# %%
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_openbookqa = load_dataset("openbookqa", "main", split="validation")  # 加载 OpenBookQA 数据
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_openbookqa = Evaluator_OpenBookQA(dataset_openbookqa, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/9.06k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/496k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/58.2k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4957 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# ### COPA

# %%
from torch.amp import autocast

class Evaluator_COPA:
    def __init__(self, dataset, tokenizer, device):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.device = device

    @torch.no_grad()
    def evaluate(self, model):
        model.to(self.device)
        model.eval()

        total, hit = 0, 0
        for sample in self.dataset:
            premise = sample["premise"]
            choice1 = sample["choice1"]
            choice2 = sample["choice2"]
            question = sample["question"]  # "cause" or "effect"
            correct_label = sample["label"]  # 0 或 1

            # 根据 question 拼接文本
            if question == "cause":
                input1 = f"什么是原因？ {choice1} 因为 {premise}"
                input2 = f"什么是原因？ {choice2} 因为 {premise}"
            else:
                input1 = f"会导致什么结果？ {premise} 所以 {choice1}"
                input2 = f"会导致什么结果？ {premise} 所以 {choice2}"

            # Tokenization
            inputs = [
                self.tokenizer(text, return_tensors="pt", padding=True, truncation=True).to(self.device)
                for text in [input1, input2]
            ]

            # 计算 logits
            logits = []
            with autocast(device_type='cuda'):  # 开启混合精度推理
                for input_ids in inputs:
                    output = model(**input_ids)
                    logits.append(output.logits[:, -1, :].max().item())  # 取最大 logits 作为得分

            # 选择得分最高的选项
            pred = logits.index(max(logits))

            # 计算准确率
            hit += (pred == correct_label)
            total += 1

        acc = hit / total
        return acc

# %%
from datasets import load_dataset
from transformers import GPT2Tokenizer, OPTForCausalLM

dataset_copa = load_dataset("super_glue", "copa", split="validation",trust_remote_code=True)  # 加载 COPA 数据
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
evaluator_copa = Evaluator_COPA(dataset_copa, tokenizer, "cuda")
# Out:
# README.md:   0%|          | 0.00/18.2k [00:00<?, ?B/s]
# super_glue.py:   0%|          | 0.00/30.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/44.0k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# ## 4.计算模型大小函数

# %%
def print_model_size(model):
    # https://discuss.pytorch.org/t/finding-model-size/130275
    param_size = sum(p.nelement() * p.element_size() for p in model.parameters())
    buffer_size = sum(b.nelement() * b.element_size() for b in model.buffers())

    size_all_gb = (param_size + buffer_size) / 1024**3  # 转换为 GB
    print('Model size: {:.3f}GB'.format(size_all_gb))

# %% [markdown]
# ## 5.打印模型架构和大小

# %%
import functools
from functools import partial
import numpy as np
from tqdm import tqdm
import os

# %% [markdown]
# #### 让我们打印OPT-6.7b的模型结构

# %%
model_original_fp16 = OPTForCausalLM.from_pretrained(
    "facebook/opt-2.7b", torch_dtype=torch.float16, device_map="auto"
)
print(model_original_fp16)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.30G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.30G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# OPTForCausalLM(
#   (model): OPTModel(
#     (decoder): OPTDecoder(
#       (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#       (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#       (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#       (layers): ModuleList(
#         (0-31): 32 x OPTDecoderLayer(
#           (self_attn): OPTSdpaAttention(
#             (k_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (v_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (q_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (out_proj): Linear(in_features=2560, out_features=2560, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc2): Linear(in_features=10240, out_features=2560, bias=True)
#           (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
# )

# %%
print_model_size(model_original_fp16)
# Out:
# Model size: 4.939GB

# %%
acc_model_fp16_copa = evaluator_copa.evaluate(model_original_fp16)
print(f"COPA Accuracy: {acc_model_fp16_copa:.4f}")

acc_model_fp16_openbookqa = evaluator_openbookqa.evaluate(model_original_fp16)
print(f"OpenBookQA Accuracy: {acc_model_fp16_openbookqa:.4f}")

acc_model_fp16_winogrande = evaluator_winogrande.evaluate(model_original_fp16)
print(f"WinoGrande Accuracy: {acc_model_fp16_winogrande:.4f}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# COPA Accuracy: 0.3500
# OpenBookQA Accuracy: 0.2620
# WinoGrande Accuracy: 0.4900

# %%
acc_model_fp16_lambada = evaluator_lambada.evaluate(model_original_fp16)
print(f"LAMBADA Accuracy: {acc_model_fp16_lambada:.4f}")

acc_model_fp16_piqa = evaluator_piqa.evaluate(model_original_fp16)
print(f"PIQA Accuracy: {acc_model_fp16_piqa:.4f}")

acc_model_fp16_wsc = evaluator_wsc.evaluate(model_original_fp16)
print(f"WSC Accuracy: {acc_model_fp16_wsc:.4f}")

acc_model_fp16_arc = evaluator_arc.evaluate(model_original_fp16)
print(f"ARC Accuracy: {acc_model_fp16_arc:.4f}")

acc_model_fp16_boolq = evaluator_boolq.evaluate(model_original_fp16)
print(f"BoolQ Accuracy: {acc_model_fp16_boolq:.4f}")

acc_model_fp16_race = evaluator_race.evaluate(model_original_fp16)
print(f"RACE Accuracy: {acc_model_fp16_race:.4f}")
# 评估模型
acc_model_hellaswag = evaluator_hellaswag.evaluate(model_original_fp16)
print(f"HellaSwag Accuracy: {acc_model_hellaswag:.4f}")
del model_original_fp16
# Out:
# LAMBADA Accuracy: 0.7590
# PIQA Accuracy: 0.4990
# WSC Accuracy: 0.5018
# ARC Accuracy: 0.2375
# BoolQ Accuracy: 0.6250
# RACE Accuracy: 0.3300
# HellaSwag Accuracy: 0.2580

# %% [markdown]
# ## 6.自定义获取act_scale, 可以跳过

# %%
# origin: def get_act_scales(model, tokenizer, dataset_path num_samples=512, seq_len=512):
def get_act_scales(model, tokenizer, dataset_name, num_samples=512, seq_len=512):
    model.eval()
    device = next(model.parameters()).device
    act_scales = {}

    def stat_tensor(name, tensor):
        hidden_dim = tensor.shape[-1]
        tensor = tensor.view(-1, hidden_dim).abs().detach()
        comming_max = torch.max(tensor, dim=0)[0].float().cpu()
        if name in act_scales:
            act_scales[name] = torch.max(act_scales[name], comming_max)
        else:
            act_scales[name] = comming_max

    def stat_input_hook(m, x, y, name):
        if isinstance(x, tuple):
            x = x[0]
        stat_tensor(name, x)

    hooks = []
    for name, m in model.named_modules():
        if isinstance(m, torch.nn.Linear):
            hooks.append(
                m.register_forward_hook(functools.partial(stat_input_hook, name=name))
            )

    # 使用 datasets 库下载 Pile 数据集的验证集（或其他数据集）
    dataset = load_dataset(dataset_name, split="train")  # 你可以更改为 "train" 或其他切分
    dataset = dataset.shuffle(seed=42)

    for i in tqdm(range(num_samples)):
        input_ids = tokenizer(
            dataset[i]["text"], return_tensors="pt", max_length=seq_len, truncation=True
        ).input_ids.to(device)
        model(input_ids)

    for h in hooks:
        h.remove()

    return act_scales

# %%
act_scales = get_act_scales(
    model_fp16,
    tokenizer,
    dataset_name="Skylion007/openwebtext",  # 数据集名称
    num_samples=512,
    seq_len=512
)
print(type(act_scales))
output_path = "act_scales/opt-2.7b.pt"  # 你希望保存的路径
os.makedirs(os.path.dirname(output_path), exist_ok=True)
torch.save(act_scales, output_path)
print(f"激活值缩放因子已保存到 {output_path}")
# Out:
# README.md:   0%|          | 0.00/7.35k [00:00<?, ?B/s]
# openwebtext.py:   0%|          | 0.00/2.73k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-9a897c8f4d32> in <cell line: 0>()
# ----> 1 act_scales = get_act_scales(
#       2     model_fp16,
#       3     tokenizer,
#       4     dataset_name="Skylion007/openwebtext",  # 数据集名称
#       5     num_samples=512,
#
# <ipython-input-10-d5511ee3c559> in get_act_scales(model, tokenizer, dataset_name, num_samples, seq_len)
#      27
#      28     # 使用 datasets 库下载 Pile 数据集的验证集（或其他数据集）
# ---> 29     dataset = load_dataset(dataset_name, split="train")  # 你可以更改为 "train" 或其他切分
#      30     dataset = dataset.shuffle(seed=42)
#      31
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2059
#    2060     # Create a dataset builder
# -> 2061     builder_instance = load_dataset_builder(
#    2062         path=path,
#    2063         name=name,
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1779         download_config = download_config.copy() if download_config else DownloadConfig()
#    1780         download_config.storage_options.update(storage_options)
# -> 1781     dataset_module = dataset_module_factory(
#    1782         path,
#    1783         revision=revision,
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1611                     dynamic_modules_path=dynamic_modules_path,
#    1612                     trust_remote_code=trust_remote_code,
# -> 1613                 ).get_module()
#    1614             except EntryNotFoundError:
#    1615                 # Use the infos from the parquet export except in some cases:
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in get_module(self)
#    1261         )
#    1262         if not os.path.exists(importable_file_path):
# -> 1263             trust_remote_code = resolve_trust_remote_code(self.trust_remote_code, self.name)
#    1264             if trust_remote_code:
#    1265                 _create_importable_file(
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in resolve_trust_remote_code(trust_remote_code, repo_id)
#     121                 signal.alarm(config.TIME_OUT_REMOTE_CODE)
#     122                 while trust_remote_code is None:
# --> 123                     answer = input(
#     124                         f"The repository for {repo_id} contains custom code which must be executed to correctly "
#     125                         f"load the dataset. You can inspect the repository content at https://hf.co/datasets/{repo_id}.\n"
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## 7.在线获取对应模型的act_scale

# %%
from huggingface_hub import hf_hub_download
import torch

# 下载 `opt-6.7b.pt` 文件
model_repo = "mit-han-lab/smoothquant-scales"
filename = "opt-2.7b.pt"

file_path = hf_hub_download(repo_id=model_repo, filename=filename)

# 加载 `act_scales`
act_scales = torch.load(file_path, map_location="cpu")
act_scales = {k: v.to("cuda") for k, v in act_scales.items()}
print(act_scales["model.decoder.layers.0.self_attn.q_proj"])
# Out:
# opt-2.7b.pt:   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# tensor([4.4609, 4.0156, 3.8926,  ..., 4.8750, 3.9160, 4.5234], device='cuda:0')

# %% [markdown]
# ## 8.Smooth结果可视化

# %% [markdown]
# #### 可视化函数

# %%
# 运行推理并获取激活值和权重
@torch.no_grad()
def get_OPT_activations_and_weights(model, tokenizer, texts, layer_index = 4, channel_indexs = 200, device="cpu"):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True)

    print("outputs.hidden_states shape is ", len(outputs.hidden_states))

    activation = outputs.hidden_states[layer_index].abs()[:, :, :channel_indexs]  # 最后一层激活值，选择前100个token和通道

    q_weight = model.model.decoder.layers[layer_index].self_attn.q_proj.weight.abs()[:, :channel_indexs]
    k_weight = model.model.decoder.layers[layer_index].self_attn.k_proj.weight.abs()[:, :channel_indexs]
    v_weight = model.model.decoder.layers[layer_index].self_attn.v_proj.weight.abs()[:, :channel_indexs]

    fcs = [q_weight,  k_weight, v_weight]

    print(f"activation shape is {activation.shape} self_attn.q_proj.weight shape is {fcs[0].shape}")
    # **手动释放 outputs**
    del outputs
    torch.cuda.empty_cache()  # 清理显存缓存

    return activation, fcs

@torch.no_grad()
def apply_smoothquant_scaling(activation, weights, scales):
    device = activation.device  # 获取 activation 所在的设备
    scales = scales.to(device)  # 将 scales 移动到同一设备
    smooth_activation = activation / scales.view(1, 1, -1)
    q_proj_weight = weights[0]
    smooth_q_weight = q_proj_weight * scales.view(1, -1)
    print(f"smooth_activation_sample shape is {smooth_activation.shape} q_proj smooth_weight shape is {smooth_q_weight.shape}")

    return smooth_activation, smooth_q_weight

# 检测离群值并打印通道索引
def find_outlier_channels(activation_sample, threshold=10):
    mean = activation_sample.mean(dim=(0, 1))
    std = activation_sample.std(dim=(0, 1))
    z_scores = (activation_sample - mean) / std

    outliers = torch.where(z_scores > threshold)
    unique_channels = torch.unique(outliers[2])
    print(f"离群值所在的通道索引: {unique_channels.tolist()}")

# 3D 绘图函数
def plot_3d(data, title, xlabel, ylabel, zlabel, color, ax, y_max):
    x, y = np.meshgrid(np.arange(data.shape[1]), np.arange(data.shape[0]))
    x, y = x.flatten(), y.flatten()
    z = np.zeros_like(x)
    dx = dy = 1
    dz = data.flatten()
    ax.bar3d(x, y, z, dx, dy, dz, color=color, zsort='average')
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_zlabel(zlabel)
    ax.set_zlim(0, y_max)  # 设置统一的 y 轴范围

# %% [markdown]
# #### 选择model类型、输入、观察的layer-index和channel数

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 处理输入文本并获取激活值和权重
input_texts = [
  "The quick brown fox jumps over the lazy dog. " * 2,  # 通过重复句子生成超过64个词的文本
  "Artificial intelligence is revolutionizing the world. " * 2,
  "Large language models are powerful tools for NLP tasks. " * 2,
  "The meaning of life is to find " * 2
  ]
layer_index = 30
channel_index = 800
activation_sample, weight_sample = get_OPT_activations_and_weights(model_fp16, tokenizer, input_texts, layer_index = layer_index,  channel_indexs=channel_index, device=device)

# %% [markdown]
# #### 打印最终的图表

# %%
# 检查离群值所在通道
find_outlier_channels(activation_sample)


# 找到act_scale
specific_location = f"model.decoder.layers.{layer_index}.self_attn.q_proj"
scales = act_scales[specific_location]
scales = scales[:channel_index]
smooth_activation_sample, smooth_weight_sample = apply_smoothquant_scaling(activation_sample, weight_sample, scales)

# 确定所有图的统一 y 轴范围
y_max = max(
    np.max(activation_sample.cpu().numpy()),
    np.max(smooth_activation_sample.cpu().numpy()),
    np.max(weight_sample[0].cpu().numpy()),
    np.max(smooth_weight_sample.cpu().numpy())
        )

# 创建图表
fig = plt.figure(figsize=(18, 8))
batch_size, seq_len, hidden_size = activation_sample.shape
activation_sample = activation_sample.view(-1, hidden_size)
smooth_activation_sample = smooth_activation_sample.view(-1, hidden_size)

# 绘制原始和平滑后的激活值和权重, weight_sample 是 q、k、v 映射层权重组合的列表
plot_titles = [
    ("Activation (Original)\nHard to quantize", activation_sample, "brown"),
    ("Activation (SmoothQuant)\nEasy to quantize", smooth_activation_sample, "blue"),
    ("Weight (Original)\nVery easy to quantize", weight_sample[0], "blue"),
    ("Weight (SmoothQuant)\nHarder but still easy to quantize", smooth_weight_sample, "blue")
        ]

for i, (title, data, color) in enumerate(plot_titles, start=1):
    ax = fig.add_subplot(1, 4, i, projection='3d')
    xlabel = "Channel" if "Activation" in title else "In Channel"
    ylabel = "Token" if "Activation" in title else "Out Channel"
    plot_3d(data.detach().cpu().numpy(), title, xlabel, ylabel, "Absolute Value", color, ax, y_max)

# 添加主标题并保存图表
fig.suptitle("SmoothQuant Visualization", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.show()  # 仅显示，不保存
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# outputs.hidden_states shape is  33
# activation shape is torch.Size([4, 24, 800]) self_attn.q_proj.weight shape is torch.Size([4096, 800])
# 离群值所在的通道索引: []
# smooth_activation_sample shape is torch.Size([4, 24, 800]) q_proj smooth_weight shape is torch.Size([4096, 800])

# %% [markdown]
# ## 9.smooth操作

# %% [markdown]
# #### 普通量化

# %%
import torch
from torch import nn
from functools import partial


@torch.no_grad()
def quantize_weight_per_channel_absmax(w, n_bits=8):
    # w: (out_features, in_features)
    scales = w.abs().max(dim=-1, keepdim=True)[0]
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    w.div_(scales).round_().mul_(scales)
    return w


@torch.no_grad()
def quantize_weight_per_tensor_absmax(w, n_bits=8):
    # w: (out_features, in_features)
    scales = w.abs().max()
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    w.div_(scales).round_().mul_(scales)
    return w


@torch.no_grad()
def quantize_activation_per_token_absmax(t, n_bits=8):
    t_shape = t.shape
    t.view(-1, t_shape[-1])
    scales = t.abs().max(dim=-1, keepdim=True)[0]
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    t.div_(scales).round_().mul_(scales)
    return t


@torch.no_grad()
def quantize_activation_per_tensor_absmax(t, n_bits=8):
    t_shape = t.shape
    t.view(-1, t_shape[-1])
    scales = t.abs().max()
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    t.div_(scales).round_().mul_(scales)
    return t


class W8A8Linear(nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        bias=True,
        act_quant="per_token",
        quantize_output=False,
    ):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features

        self.register_buffer(
            "weight",
            torch.randn(
                self.out_features,
                self.in_features,
                dtype=torch.float16,
                requires_grad=False,
            ),
        )
        if bias:
            self.register_buffer(
                "bias",
                torch.zeros(
                    (1, self.out_features), dtype=torch.float16, requires_grad=False
                ),
            )
        else:
            self.register_buffer("bias", None)

        if act_quant == "per_token":
            self.act_quant_name = "per_token"
            self.act_quant = partial(quantize_activation_per_token_absmax, n_bits=8)
        elif act_quant == "per_tensor":
            self.act_quant_name = "per_tensor"
            self.act_quant = partial(quantize_activation_per_tensor_absmax, n_bits=8)
        else:
            raise ValueError(f"Invalid act_quant: {act_quant}")

        if quantize_output:
            self.output_quant_name = self.act_quant_name
            self.output_quant = self.act_quant
        else:
            self.output_quant_name = "None"
            self.output_quant = lambda x: x

    def to(self, *args, **kwargs):
        super(W8A8Linear, self).to(*args, **kwargs)
        self.weight = self.weight.to(*args, **kwargs)
        if self.bias is not None:
            self.bias = self.bias.to(*args, **kwargs)
        return self

    @torch.no_grad()
    def forward(self, x):
        q_x = self.act_quant(x)
        y = torch.functional.F.linear(q_x, self.weight, self.bias)
        q_y = self.output_quant(y)
        return q_y

    @staticmethod
    def from_float(
        module, weight_quant="per_channel", act_quant="per_token", quantize_output=False
    ):
        assert isinstance(module, torch.nn.Linear)
        new_module = W8A8Linear(
            module.in_features,
            module.out_features,
            module.bias is not None,
            act_quant=act_quant,
            quantize_output=quantize_output,
        )
        if weight_quant == "per_channel":
            new_module.weight = quantize_weight_per_channel_absmax(
                module.weight, n_bits=8
            )  # use 8-bit integer for weight
        elif weight_quant == "per_tensor":
            new_module.weight = quantize_weight_per_tensor_absmax(
                module.weight, n_bits=8
            )
        else:
            raise ValueError(f"Invalid weight_quant: {weight_quant}")
        new_module.weight_quant_name = weight_quant
        if module.bias is not None:
            new_module.bias = module.bias
        return new_module

    def __repr__(self):
        return f"W8A8Linear({self.in_features}, {self.out_features}, bias={self.bias is not None}, weight_quant={self.weight_quant_name}, act_quant={self.act_quant_name}, output_quant={self.output_quant_name})"


def naive_quantize_opt(
    model, weight_quant="per_tensor", act_quant="per_tensor", quantize_bmm_input=True
):
    from transformers.models.opt.modeling_opt import (
        OPTAttention,
        OPTDecoderLayer,
    )

    for name, m in model.model.named_modules():
        if isinstance(m, OPTDecoderLayer):
            m.fc1 = W8A8Linear.from_float(
                m.fc1, weight_quant=weight_quant, act_quant=act_quant
            )
            m.fc2 = W8A8Linear.from_float(
                m.fc2, weight_quant=weight_quant, act_quant=act_quant
            )
        elif isinstance(m, OPTAttention):
            # Her we simulate quantizing BMM inputs by quantizing the output of q_proj, k_proj, v_proj
            m.q_proj = W8A8Linear.from_float(
                m.q_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.k_proj = W8A8Linear.from_float(
                m.k_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.v_proj = W8A8Linear.from_float(
                m.v_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.out_proj = W8A8Linear.from_float(
                m.out_proj, weight_quant=weight_quant, act_quant=act_quant
            )
    return model


def naive_quantize_llama_like(
    model, weight_quant="per_channel", act_quant="per_token", quantize_bmm_input=False
):
    from transformers.models.llama.modeling_llama import (
        LlamaAttention,
        LlamaMLP,
    )

    from transformers.models.mistral.modeling_mistral import (
        MistralAttention,
        MistralMLP,
    )

    for name, m in model.model.named_modules():
        if isinstance(m, (LlamaMLP, MistralMLP)):
            m.gate_proj = W8A8Linear.from_float(
                m.gate_proj, weight_quant=weight_quant, act_quant=act_quant
            )
            m.up_proj = W8A8Linear.from_float(
                m.up_proj, weight_quant=weight_quant, act_quant=act_quant
            )
            m.down_proj = W8A8Linear.from_float(
                m.down_proj, weight_quant=weight_quant, act_quant=act_quant
            )
        elif isinstance(m, (LlamaAttention, MistralAttention)):
            # Her we simulate quantizing BMM inputs by quantizing the output of q_proj, k_proj, v_proj
            m.q_proj = W8A8Linear.from_float(
                m.q_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.k_proj = W8A8Linear.from_float(
                m.k_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.v_proj = W8A8Linear.from_float(
                m.v_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
            )
            m.o_proj = W8A8Linear.from_float(
                m.o_proj, weight_quant=weight_quant, act_quant=act_quant
            )
    return model

# %% [markdown]
# #### AWQ+Smooth

# %%
import torch
from torch import nn
from functools import partial


@torch.no_grad()
def quantize_weight_per_channel_absmax(w, n_bits=8):
    scales = w.abs().max(dim=-1, keepdim=True)[0]
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    w.div_(scales).round_().mul_(scales)
    return w


@torch.no_grad()
def quantize_weight_per_tensor_absmax(w, n_bits=8):
    scales = w.abs().max()
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    w.div_(scales).round_().mul_(scales)
    return w


@torch.no_grad()
def quantize_activation_per_token_absmax(t, n_bits=8):
    t_shape = t.shape
    t.view(-1, t_shape[-1])
    scales = t.abs().max(dim=-1, keepdim=True)[0]
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    t.div_(scales).round_().mul_(scales)
    return t


@torch.no_grad()
def quantize_activation_per_tensor_absmax(t, n_bits=8):
    t_shape = t.shape
    t.view(-1, t_shape[-1])
    scales = t.abs().max()
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    t.div_(scales).round_().mul_(scales)
    return t


def find_significant_weights(w, top_n_percent=1):
    # 按绝对值排序，选择top_n%作为显著权重
    abs_weights = w.abs()
    num_significant = max(1, int(w.numel() * top_n_percent / 100))  # 至少保留1个显著权重
    significant_weights, _ = torch.topk(abs_weights.view(-1), num_significant)
    threshold = significant_weights.min()
    # 找到大于等于阈值的权重，标记为显著权重
    significant_mask = abs_weights >= threshold
    return significant_mask


class AWQLinear(nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        bias=True,
        act_quant="per_token",
        quantize_output=False,
        top_n_percent=1,  # 新增参数：显著权重百分比
    ):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.top_n_percent = top_n_percent

        self.register_buffer(
            "weight",
            torch.randn(
                self.out_features,
                self.in_features,
                dtype=torch.float16,
                requires_grad=False,
            ),
        )
        if bias:
            self.register_buffer(
                "bias",
                torch.zeros(
                    (1, self.out_features), dtype=torch.float16, requires_grad=False
                ),
            )
        else:
            self.register_buffer("bias", None)

        # 激活量化策略
        if act_quant == "per_token":
            self.act_quant_name = "per_token"
            self.act_quant = partial(quantize_activation_per_token_absmax, n_bits=8)
        elif act_quant == "per_tensor":
            self.act_quant_name = "per_tensor"
            self.act_quant = partial(quantize_activation_per_tensor_absmax, n_bits=8)
        else:
            raise ValueError(f"Invalid act_quant: {act_quant}")

        # 输出量化策略
        if quantize_output:
            self.output_quant_name = self.act_quant_name
            self.output_quant = self.act_quant
        else:
            self.output_quant_name = "None"
            self.output_quant = lambda x: x

    def to(self, *args, **kwargs):
        super(AWQLinear, self).to(*args, **kwargs)
        self.weight = self.weight.to(*args, **kwargs)
        if self.bias is not None:
            self.bias = self.bias.to(*args, **kwargs)
        return self

    @torch.no_grad()
    def forward(self, x):
        # 选择显著权重
        significant_mask = find_significant_weights(self.weight, self.top_n_percent)
        significant_weights = self.weight * significant_mask.float()  # 保留显著权重

        # 对其余权重进行量化
        non_significant_weights = self.weight * (1 - significant_mask.float())
        quantized_weights = quantize_weight_per_channel_absmax(non_significant_weights, n_bits=8)
        quantized_weights += significant_weights  # 显著权重保留不变

        # 对输入激活进行量化
        q_x = self.act_quant(x)

        # 使用量化后的权重进行线性变换
        y = torch.functional.F.linear(q_x, quantized_weights, self.bias)

        # 对输出激活进行量化
        q_y = self.output_quant(y)
        return q_y

    @staticmethod
    def from_float(
        module, weight_quant="per_channel", act_quant="per_token", quantize_output=False, top_n_percent=1
    ):
        assert isinstance(module, torch.nn.Linear)
        new_module = AWQLinear(
            module.in_features,
            module.out_features,
            module.bias is not None,
            act_quant=act_quant,
            quantize_output=quantize_output,
            top_n_percent=top_n_percent,
        )
        if weight_quant == "per_channel":
            new_module.weight = quantize_weight_per_channel_absmax(
                module.weight, n_bits=8
            )
        elif weight_quant == "per_tensor":
            new_module.weight = quantize_weight_per_tensor_absmax(
                module.weight, n_bits=8
            )
        else:
            raise ValueError(f"Invalid weight_quant: {weight_quant}")
        new_module.weight_quant_name = weight_quant
        if module.bias is not None:
            new_module.bias = module.bias
        return new_module

    def __repr__(self):
        return f"AWQLinear({self.in_features}, {self.out_features}, bias={self.bias is not None}, weight_quant={self.weight_quant_name}, act_quant={self.act_quant_name}, output_quant={self.output_quant_name})"


def AWQ_quantize_opt(
    model, weight_quant="per_tensor", act_quant="per_tensor", quantize_bmm_input=True, top_n_percent=1
):
    from transformers.models.opt.modeling_opt import (
        OPTAttention,
        OPTDecoderLayer,
    )

    for name, m in model.model.named_modules():
        if isinstance(m, OPTDecoderLayer):
            m.fc1 = AWQLinear.from_float(
                m.fc1, weight_quant=weight_quant, act_quant=act_quant, top_n_percent=top_n_percent
            )
            m.fc2 = AWQLinear.from_float(
                m.fc2, weight_quant=weight_quant, act_quant=act_quant, top_n_percent=top_n_percent
            )
        elif isinstance(m, OPTAttention):
            m.q_proj = AWQLinear.from_float(
                m.q_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
                top_n_percent=top_n_percent,
            )
            m.k_proj = AWQLinear.from_float(
                m.k_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
                top_n_percent=top_n_percent,
            )
            m.v_proj = AWQLinear.from_float(
                m.v_proj,
                weight_quant=weight_quant,
                act_quant=act_quant,
                quantize_output=quantize_bmm_input,
                top_n_percent=top_n_percent,
            )
            m.out_proj = AWQLinear.from_float(
                m.out_proj, weight_quant=weight_quant, act_quant=act_quant, top_n_percent=top_n_percent
            )
    return model

# %% [markdown]
# #### smooth+W8A8+AWQ

# %%
my_act_scales = torch.load(file_path)
model_original_fp16 = OPTForCausalLM.from_pretrained(
    "facebook/opt-2.7b", torch_dtype=torch.float16, device_map="auto"
)
smooth_lm(model_original_fp16, my_act_scales, 0.5)
model_W8A8_AWQ = AWQ_quantize_opt(model_original_fp16, weight_quant="per_channel")

print_model_size(model_W8A8_AWQ)
# Out:
# Model size: 4.939GB

# %% [markdown]
# #### 评估

# %%
# 评估 W8A8_AWQ 量化模型
acc_model_W8A8_AWQ_copa = evaluator_copa.evaluate(model_W8A8_AWQ)
print(f"COPA Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_copa:.4f}")

acc_model_W8A8_AWQ_openbookqa = evaluator_openbookqa.evaluate(model_W8A8_AWQ)
print(f"OpenBookQA Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_openbookqa:.4f}")

acc_model_W8A8_AWQ_winogrande = evaluator_winogrande.evaluate(model_W8A8_AWQ)
print(f"WinoGrande Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_winogrande:.4f}")
# Out:
# COPA Accuracy (W8A8_AWQ): 0.4200
# OpenBookQA Accuracy (W8A8_AWQ): 0.2640
# WinoGrande Accuracy (W8A8_AWQ): 0.4830

# %%
# 评估
acc_model_W8A8_AWQ_lambada = evaluator_lambada.evaluate(model_W8A8_AWQ)
print(f"LAMBADA Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_lambada:.4f}")

acc_model_W8A8_AWQ_piqa = evaluator_piqa.evaluate(model_W8A8_AWQ)
print(f"PIQA Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_piqa:.4f}")

acc_model_W8A8_AWQ_wsc = evaluator_wsc.evaluate(model_W8A8_AWQ)
print(f"WSC Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_wsc:.4f}")

acc_model_W8A8_AWQ_arc = evaluator_arc.evaluate(model_W8A8_AWQ)
print(f"ARC Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_arc:.4f}")

acc_model_W8A8_AWQ_boolq = evaluator_boolq.evaluate(model_W8A8_AWQ)
print(f"BoolQ Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_boolq:.4f}")

acc_model_W8A8_AWQ_race = evaluator_race.evaluate(model_W8A8_AWQ)
print(f"RACE Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_race:.4f}")

acc_model_W8A8_AWQ_hellaswag = evaluator_hellaswag.evaluate(model_W8A8_AWQ)
print(f"HellaSwag Accuracy (W8A8_AWQ): {acc_model_W8A8_AWQ_hellaswag:.4f}")
del model_original_fp16  # 删除原始模型
del model_W8A8_AWQ       # 删除量化模型
# Out:
# LAMBADA Accuracy (W8A8_AWQ): 0.7630
# PIQA Accuracy (W8A8_AWQ): 0.4800
# WSC Accuracy (W8A8_AWQ): 0.5018
# ARC Accuracy (W8A8_AWQ): 0.2542
# BoolQ Accuracy (W8A8_AWQ): 0.6250
# RACE Accuracy (W8A8_AWQ): 0.3320
# HellaSwag Accuracy (W8A8_AWQ): 0.2510

# %% [markdown]
# LAMBADA Accuracy: 0.7590
# PIQA Accuracy: 0.4990
# WSC Accuracy: 0.5018
# ARC Accuracy: 0.2341
# BoolQ Accuracy: 0.6250
# RACE Accuracy: 0.3290
# HellaSwag Accuracy: 0.2570

# %%
# 保存模型
save_path = "smooth_W8A8_AWQ_model"
model_W8A8_AWQ.save_pretrained(save_path)
tokenizer = GPT2Tokenizer.from_pretrained("facebook/opt-2.7b")
tokenizer.save_pretrained(save_path)

# %% [markdown]
# #### smooth + W8A8

# %%
my_act_scales = torch.load(file_path)
model_original_fp16 = OPTForCausalLM.from_pretrained(
    "facebook/opt-2.7b", torch_dtype=torch.float16, device_map="auto"
)
smooth_lm(model_original_fp16, my_act_scales, 0.5)
model_W8A8_Naive = naive_quantize_opt(model_original_fp16, weight_quant="per_channel")

# %%
# 评估 W8A8_Naive 量化模型
acc_model_W8A8_Naive_copa = evaluator_copa.evaluate(model_W8A8_Naive)
print(f"COPA Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_copa:.4f}")

acc_model_W8A8_Naive_openbookqa = evaluator_openbookqa.evaluate(model_W8A8_Naive)
print(f"OpenBookQA Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_openbookqa:.4f}")

acc_model_W8A8_Naive_winogrande = evaluator_winogrande.evaluate(model_W8A8_Naive)
print(f"WinoGrande Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_winogrande:.4f}")
# Out:
# COPA Accuracy (W8A8_Naive): 0.4000
# OpenBookQA Accuracy (W8A8_Naive): 0.2660
# WinoGrande Accuracy (W8A8_Naive): 0.4940

# %%
# 评估
acc_model_W8A8_Naive_lambada = evaluator_lambada.evaluate(model_W8A8_Naive)
print(f"LAMBADA Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_lambada:.4f}")

acc_model_W8A8_Naive_piqa = evaluator_piqa.evaluate(model_W8A8_Naive)
print(f"PIQA Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_piqa:.4f}")

acc_model_W8A8_Naive_wsc = evaluator_wsc.evaluate(model_W8A8_Naive)
print(f"WSC Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_wsc:.4f}")

acc_model_W8A8_Naive_arc = evaluator_arc.evaluate(model_W8A8_Naive)
print(f"ARC Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_arc:.4f}")

acc_model_W8A8_Naive_boolq = evaluator_boolq.evaluate(model_W8A8_Naive)
print(f"BoolQ Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_boolq:.4f}")

acc_model_W8A8_Naive_race = evaluator_race.evaluate(model_W8A8_Naive)
print(f"RACE Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_race:.4f}")

acc_model_W8A8_Naive_hellaswag = evaluator_hellaswag.evaluate(model_W8A8_Naive)
print(f"HellaSwag Accuracy (W8A8_Naive): {acc_model_W8A8_Naive_hellaswag:.4f}")

del model_original_fp16  # 删除原始模型
del model_W8A8_Naive       # 删除量化模型
# Out:
# LAMBADA Accuracy (W8A8_Naive): 0.7590
# PIQA Accuracy (W8A8_Naive): 0.4890
# WSC Accuracy (W8A8_Naive): 0.5018
# ARC Accuracy (W8A8_Naive): 0.2341
# BoolQ Accuracy (W8A8_Naive): 0.6250
# RACE Accuracy (W8A8_Naive): 0.3360
# HellaSwag Accuracy (W8A8_Naive): 0.2550

# %% [markdown]
# #### 不smooth，直接W8A8

# %%
model_original_fp16 = OPTForCausalLM.from_pretrained(
    "facebook/opt-2.7b", torch_dtype=torch.float16, device_map="auto"
)
model_W8A8_Naive_Without_Smooth = naive_quantize_opt(model_original_fp16, weight_quant="per_channel")

# %%
# 评估 W8A8_Naive_Without_Smooth 量化模型
acc_model_W8A8_Naive_Without_Smooth_copa = evaluator_copa.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"COPA Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_copa:.4f}")

acc_model_W8A8_Naive_Without_Smooth_openbookqa = evaluator_openbookqa.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"OpenBookQA Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_openbookqa:.4f}")

acc_model_W8A8_Naive_Without_Smooth_winogrande = evaluator_winogrande.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"WinoGrande Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_winogrande:.4f}")
# Out:
# COPA Accuracy (W8A8_Naive_Without_Smooth): 0.4600
# OpenBookQA Accuracy (W8A8_Naive_Without_Smooth): 0.2660
# WinoGrande Accuracy (W8A8_Naive_Without_Smooth): 0.5030

# %%
# 评估
acc_model_W8A8_Naive_Without_Smooth_lambada = evaluator_lambada.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"LAMBADA Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_lambada:.4f}")

acc_model_W8A8_Naive_Without_Smooth_piqa = evaluator_piqa.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"PIQA Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_piqa:.4f}")

acc_model_W8A8_Naive_Without_Smooth_wsc = evaluator_wsc.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"WSC Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_wsc:.4f}")

acc_model_W8A8_Naive_Without_Smooth_arc = evaluator_arc.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"ARC Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_arc:.4f}")

acc_model_W8A8_Naive_Without_Smooth_boolq = evaluator_boolq.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"BoolQ Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_boolq:.4f}")

acc_model_W8A8_Naive_Without_Smooth_race = evaluator_race.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"RACE Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_race:.4f}")

acc_model_W8A8_Naive_Without_Smooth_hellaswag = evaluator_hellaswag.evaluate(model_W8A8_Naive_Without_Smooth)
print(f"HellaSwag Accuracy (W8A8_Naive_Without_Smooth): {acc_model_W8A8_Naive_Without_Smooth_hellaswag:.4f}")

del model_original_fp16
del model_W8A8_Naive_Without_Smooth
# Out:
# LAMBADA Accuracy (W8A8_Naive_Without_Smooth): 0.7480
# PIQA Accuracy (W8A8_Naive_Without_Smooth): 0.4870
# WSC Accuracy (W8A8_Naive_Without_Smooth): 0.5018
# ARC Accuracy (W8A8_Naive_Without_Smooth): 0.2441
# BoolQ Accuracy (W8A8_Naive_Without_Smooth): 0.6250
# RACE Accuracy (W8A8_Naive_Without_Smooth): 0.3130
# HellaSwag Accuracy (W8A8_Naive_Without_Smooth): 0.2550

# %%
print(f"Quantized model size:{calculate_model_size(model_W8A8_Naive_Without_Smooth):.2f}GB")
# Out:
# Quantized model size:4.94GB

# %% [markdown]
# #### 不smooth，直接W8A8+AWQ

# %%
model_original_fp16 = OPTForCausalLM.from_pretrained(
    "facebook/opt-2.7b", torch_dtype=torch.float16, device_map="auto"
)
model_W8A8_AWQ_Without_Smooth = AWQ_quantize_opt(model_original_fp16, weight_quant="per_channel")

# %%
# 评估 W8A8_AWQ_Without_Smooth 量化模型
acc_model_W8A8_AWQ_Without_Smooth_copa = evaluator_copa.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"COPA Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_copa:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_openbookqa = evaluator_openbookqa.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"OpenBookQA Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_openbookqa:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_winogrande = evaluator_winogrande.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"WinoGrande Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_winogrande:.4f}")
# Out:
# COPA Accuracy (W8A8_AWQ_Without_Smooth): 0.4600
# OpenBookQA Accuracy (W8A8_AWQ_Without_Smooth): 0.2440
# WinoGrande Accuracy (W8A8_AWQ_Without_Smooth): 0.5090

# %%
# 评估
acc_model_W8A8_AWQ_Without_Smooth_lambada = evaluator_lambada.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"LAMBADA Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_lambada:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_piqa = evaluator_piqa.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"PIQA Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_piqa:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_wsc = evaluator_wsc.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"WSC Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_wsc:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_arc = evaluator_arc.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"ARC Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_arc:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_boolq = evaluator_boolq.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"BoolQ Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_boolq:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_race = evaluator_race.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"RACE Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_race:.4f}")

acc_model_W8A8_AWQ_Without_Smooth_hellaswag = evaluator_hellaswag.evaluate(model_W8A8_AWQ_Without_Smooth)
print(f"HellaSwag Accuracy (W8A8_AWQ_Without_Smooth): {acc_model_W8A8_AWQ_Without_Smooth_hellaswag:.4f}")


del model_original_fp16
del model_W8A8_AWQ_Without_Smooth
# Out:
# LAMBADA Accuracy (W8A8_AWQ_Without_Smooth): 0.7490
# PIQA Accuracy (W8A8_AWQ_Without_Smooth): 0.5000
# WSC Accuracy (W8A8_AWQ_Without_Smooth): 0.5018
# ARC Accuracy (W8A8_AWQ_Without_Smooth): 0.2609
# BoolQ Accuracy (W8A8_AWQ_Without_Smooth): 0.6250
# RACE Accuracy (W8A8_AWQ_Without_Smooth): 0.3100
# HellaSwag Accuracy (W8A8_AWQ_Without_Smooth): 0.2550

# %%
print(f"Quantized model size:{calculate_model_size(model_W8A8_AWQ_Without_Smooth):.2f}GB")
# Out:
# Quantized model size:4.94GB

# %% [markdown]
# #### 保存smooth后的模型

# %%
save_path = "smooth_model"
model_smoothed_fp16.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)  # 也保存分词器
print(f"Smooth model is saved at {save_path}")
# Out:
# Smooth model is saved at smooth_model

# %%
save_path = "smoothed_model"
quantized_model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)  # 也保存分词器
print(f"Smooth model is saved at {save_path}")
# Out:
# Smooth model is saved at smoothed_A8_model

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=smoothed_A8_model \
    --tasks hellaswag,lambada,piqa \
    --device cuda:1 \
    --batch_size 4
# Out:
# 2025-04-02 21:16:41.423704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743628601.444638    7061 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743628601.450973    7061 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-02:21:16:47 INFO     [__main__:422] Selected Tasks: ['hellaswag', 'lambada', 'piqa']
# 2025-04-02:21:16:47 INFO     [evaluator:180] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-04-02:21:16:47 INFO     [evaluator:218] Initializing hf model, with arguments: {'pretrained': 'smoothed_A8_model'}
# 2025-04-02:21:16:47 INFO     [models.huggingface:144] Device not specified
# 2025-04-02:21:16:47 INFO     [models.huggingface:145] Cuda Available? True
# 2025-04-02:21:16:48 INFO     [models.huggingface:377] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.04s/it]
# README.md: 100% 6.84k/6.84k [00:00<00:00, 33.1MB/s]
# hellaswag.py: 100% 4.36k/4.36k [00:00<00:00, 21.7MB/s]
# dataset_infos.json: 100% 2.53k/2.53k [00:00<00:00, 18.9MB/s]
# Downloading data: 100% 47.5M/47.5M [00:00<00:00, 362MB/s]
# Downloading data: 100% 11.8M/11.8M [00:00<00:00, 372MB/s]
# Downloading data: 100% 12.2M/12.2M [00:00<00:00, 379MB/s]
# Generating train split: 100% 39905/39905 [00:02<00:00, 14221.36 examples/s]
# Generating test split: 100% 10003/10003 [00:00<00:00, 14307.89 examples/s]
# Generating validation split: 100% 10042/10042 [00:00<00:00, 14363.73 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6235.30 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6922.81 examples/s]
# README.md: 100% 7.32k/7.32k [00:00<00:00, 33.1MB/s]
# train-00000-of-00002.parquet: 100% 269M/269M [00:00<00:00, 409MB/s]
# train-00001-of-00002.parquet: 100% 281M/281M [00:00<00:00, 383MB/s]
# test-00000-of-00001.parquet: 100% 1.14M/1.14M [00:00<00:00, 224MB/s]
# validation-00000-of-00001.parquet: 100% 1.08M/1.08M [00:00<00:00, 284MB/s]
# Generating train split: 100% 2662/2662 [00:07<00:00, 368.37 examples/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 412324.94 examples/s]
# Generating validation split: 100% 4869/4869 [00:00<00:00, 494924.42 examples/s]
# README.md: 100% 4.99k/4.99k [00:00<00:00, 29.2MB/s]
# lambada_openai.py: 100% 4.82k/4.82k [00:00<00:00, 28.0MB/s]
# 0000.parquet: 100% 1.16M/1.16M [00:00<00:00, 77.6MB/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 547046.20 examples/s]
# piqa_train.parquet: 100% 2.64M/2.64M [00:00<00:00, 175MB/s]
# piqa_validation.parquet: 100% 300k/300k [00:00<00:00, 131MB/s]
# piqa_test.parquet: 100% 496k/496k [00:00<00:00, 176MB/s]
# Generating train split: 100% 16113/16113 [00:00<00:00, 1076365.23 examples/s]
# Generating validation split: 100% 1838/1838 [00:00<00:00, 521662.66 examples/s]
# Generating test split: 100% 3084/3084 [00:00<00:00, 745374.76 examples/s]
# 2025-04-02:21:17:49 INFO     [api.task:426] Building contexts for piqa on rank 0...
# 100% 1838/1838 [00:01<00:00, 1114.02it/s]
# 2025-04-02:21:17:50 INFO     [api.task:426] Building contexts for lambada_openai on rank 0...
# 100% 5153/5153 [00:08<00:00, 600.94it/s]
# 2025-04-02:21:17:59 INFO     [api.task:426] Building contexts for lambada_standard on rank 0...
# 100% 5153/5153 [00:08<00:00, 598.03it/s]
# 2025-04-02:21:18:08 INFO     [api.task:426] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2422.47it/s]
# 2025-04-02:21:18:13 INFO     [evaluator:542] Running loglikelihood requests
# Running loglikelihood requests: 100% 54150/54150 [04:20<00:00, 207.49it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.25it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.67it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-04-02:21:23:29 INFO     [loggers.evaluation_tracker:272] Output path not provided, skipping saving results aggregated
# hf (pretrained=smoothed_A8_model), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 4
# |     Tasks      |Version|Filter|n-shot|  Metric  |   |Value |   |Stderr|
# |----------------|------:|------|-----:|----------|---|-----:|---|-----:|
# |hellaswag       |      1|none  |     0|acc       |↑  |0.4585|±  |0.0050|
# |                |       |none  |     0|acc_norm  |↑  |0.6062|±  |0.0049|
# |lambada_openai  |      1|none  |     0|acc       |↑  |0.6357|±  |0.0067|
# |                |       |none  |     0|perplexity|↓  |5.1193|±  |0.1197|
# |lambada_standard|      1|none  |     0|acc       |↑  |0.5591|±  |0.0069|
# |                |       |none  |     0|perplexity|↓  |7.4144|±  |0.1975|
# |piqa            |      1|none  |     0|acc       |↑  |0.7383|±  |0.0103|
# |                |       |none  |     0|acc_norm  |↑  |0.7481|±  |0.0101|

# %% [markdown]
# #### smooth后模型精度

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=smooth_model \
    --tasks hellaswag,lambada,piqa \
    --device cuda:0 \
    --batch_size 4
# Out:
# 2025-04-02 20:12:19.217216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743624739.238993   20058 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743624739.245629   20058 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-02:20:12:25 INFO     [__main__:422] Selected Tasks: ['hellaswag', 'lambada', 'piqa']
# 2025-04-02:20:12:25 INFO     [evaluator:180] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-04-02:20:12:25 INFO     [evaluator:218] Initializing hf model, with arguments: {'pretrained': 'smooth_model'}
# 2025-04-02:20:12:25 INFO     [models.huggingface:136] Using device 'cuda:0'
# 2025-04-02:20:12:26 INFO     [models.huggingface:377] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# Loading checkpoint shards: 100% 3/3 [00:04<00:00,  1.53s/it]
# 2025-04-02:20:12:54 INFO     [api.task:426] Building contexts for piqa on rank 0...
# 100% 1838/1838 [00:01<00:00, 1103.56it/s]
# 2025-04-02:20:12:56 INFO     [api.task:426] Building contexts for lambada_openai on rank 0...
# 100% 5153/5153 [00:08<00:00, 598.13it/s]
# 2025-04-02:20:13:04 INFO     [api.task:426] Building contexts for lambada_standard on rank 0...
# 100% 5153/5153 [00:08<00:00, 596.30it/s]
# 2025-04-02:20:13:13 INFO     [api.task:426] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2401.93it/s]
# 2025-04-02:20:13:19 INFO     [evaluator:542] Running loglikelihood requests
# Running loglikelihood requests: 100% 54150/54150 [06:10<00:00, 146.05it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.48it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.59it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-04-02:20:20:24 INFO     [loggers.evaluation_tracker:272] Output path not provided, skipping saving results aggregated
# hf (pretrained=smooth_model), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 4
# |     Tasks      |Version|Filter|n-shot|  Metric  |   |Value |   |Stderr|
# |----------------|------:|------|-----:|----------|---|-----:|---|-----:|
# |hellaswag       |      1|none  |     0|acc       |↑  |0.5049|±  |0.0050|
# |                |       |none  |     0|acc_norm  |↑  |0.6720|±  |0.0047|
# |lambada_openai  |      1|none  |     0|acc       |↑  |0.6765|±  |0.0065|
# |                |       |none  |     0|perplexity|↓  |4.2520|±  |0.0928|
# |lambada_standard|      1|none  |     0|acc       |↑  |0.6324|±  |0.0067|
# |                |       |none  |     0|perplexity|↓  |5.2172|±  |0.1222|
# |piqa            |      1|none  |     0|acc       |↑  |0.7628|±  |0.0099|
# |                |       |none  |     0|acc_norm  |↑  |0.7650|±  |0.0099|

# %%
import torch
from torch import nn


@torch.no_grad()
def quantize_weight_per_channel_absmax(w, n_bits=8):
    scales = w.abs().max(dim=-1, keepdim=True)[0]
    q_max = 2 ** (n_bits - 1) - 1
    scales.clamp_(min=1e-5).div_(q_max)
    w.div_(scales).round_().mul_(scales)
    return w


class W8A8Linear(nn.Module):
    def __init__(self, in_features, out_features, bias=True):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.register_buffer(
            "weight", torch.randn(out_features, in_features, dtype=torch.float16, requires_grad=False)
        )
        self.register_buffer("bias", torch.zeros((1, out_features), dtype=torch.float16, requires_grad=False) if bias else None)

    @staticmethod
    def from_float(module, weight_quant="per_channel"):
        assert isinstance(module, torch.nn.Linear)
        new_module = W8A8Linear(module.in_features, module.out_features, module.bias is not None)
        if weight_quant == "per_channel":
            new_module.weight = quantize_weight_per_channel_absmax(module.weight, n_bits=8)
        else:
            raise ValueError(f"Invalid weight_quant: {weight_quant}")
        if module.bias is not None:
            new_module.bias = module.bias
        return new_module


def quantize_opt(model, weight_quant="per_channel"):
    from transformers.models.opt.modeling_opt import OPTAttention, OPTDecoderLayer

    for name, m in model.model.named_modules():
        if isinstance(m, OPTDecoderLayer):
            m.fc1 = W8A8Linear.from_float(m.fc1, weight_quant=weight_quant)
            m.fc2 = W8A8Linear.from_float(m.fc2, weight_quant=weight_quant)
        elif isinstance(m, OPTAttention):
            m.q_proj = W8A8Linear.from_float(m.q_proj, weight_quant=weight_quant)
            m.k_proj = W8A8Linear.from_float(m.k_proj, weight_quant=weight_quant)
            m.v_proj = W8A8Linear.from_float(m.v_proj, weight_quant=weight_quant)
            m.out_proj = W8A8Linear.from_float(m.out_proj, weight_quant=weight_quant)
    return model


def quantize_llama_like(model, weight_quant="per_channel"):
    from transformers.models.llama.modeling_llama import LlamaAttention, LlamaMLP

    for name, m in model.model.named_modules():
        if isinstance(m, LlamaMLP):
            m.gate_proj = W8A8Linear.from_float(m.gate_proj, weight_quant=weight_quant)
            m.up_proj = W8A8Linear.from_float(m.up_proj, weight_quant=weight_quant)
            m.down_proj = W8A8Linear.from_float(m.down_proj, weight_quant=weight_quant)
        elif isinstance(m, LlamaAttention):
            m.q_proj = W8A8Linear.from_float(m.q_proj, weight_quant=weight_quant)
            m.k_proj = W8A8Linear.from_float(m.k_proj, weight_quant=weight_quant)
            m.v_proj = W8A8Linear.from_float(m.v_proj, weight_quant=weight_quant)
            m.o_proj = W8A8Linear.from_float(m.o_proj, weight_quant=weight_quant)
    return model

# %% [markdown]
# ## 10.AWQ量化

# %% [markdown]
# #### 加载smooth后的模型，进行权重4bit的AWQ量化

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

# 重新加载 Smooth 处理后的模型
smooth_model_path = "smooth_model"
smoothed_awq_model_W4 = AutoAWQForCausalLM.from_pretrained(smooth_model_path)
tokenizer = AutoTokenizer.from_pretrained(smooth_model_path, trust_remote_code=True)

# 进行 AWQ 量化
quant_config = {"zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM"}
smoothed_awq_model_W4.quantize(tokenizer, quant_config=quant_config)

# 保存量化后的模型
quant_path = "smooth_awq_quantized_model"
smoothed_awq_model_W4.save_quantized(quant_path)
tokenizer.save_pretrained(quant_path)

print(f"Smoothed Model with AWQ is saved at {quant_path}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# val.jsonl.zst:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/214670 [00:00<?, ? examples/s]
# AWQ: 100%|██████████| 32/32 [06:39<00:00, 12.48s/it]
# Smoothed Model with AWQ is saved at smooth_awq_quantized_model

# %% [markdown]
# #### 打印量化后模型大小

# %%
print(f"Quantized model size:{calculate_model_size(smoothed_awq_model_W4):.2f}GB")
print(smoothed_awq_model_W4)
# Out:
# Quantized model size:0.25GB
# OptAWQForCausalLM(
#   (model): OPTForCausalLM(
#     (model): OPTModel(
#       (decoder): OPTDecoder(
#         (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#         (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#         (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0-31): 32 x OPTDecoderLayer(
#             (self_attn): OPTSdpaAttention(
#               (k_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (v_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (q_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (out_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#             (fc1): WQLinear_GEMM(in_features=2560, out_features=10240, bias=True, w_bit=4, group_size=128)
#             (fc2): WQLinear_GEMM(in_features=10240, out_features=2560, bias=True, w_bit=4, group_size=128)
#             (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
#   )
# )

# %%
quantized_AWQ_model = quantize_model(smoothed_awq_model_W4, act_quant="per_token", quantize_bmm_input=True)
# Use the quantized model for inference
print(quantized_AWQ_model)
# Out:
# OptAWQForCausalLM(
#   (model): OPTForCausalLM(
#     (model): OPTModel(
#       (decoder): OPTDecoder(
#         (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#         (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#         (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0-31): 32 x OPTDecoderLayer(
#             (self_attn): OPTSdpaAttention(
#               (k_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (v_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (q_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#               (out_proj): WQLinear_GEMM(in_features=2560, out_features=2560, bias=True, w_bit=4, group_size=128)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#             (fc1): WQLinear_GEMM(in_features=2560, out_features=10240, bias=True, w_bit=4, group_size=128)
#             (fc2): WQLinear_GEMM(in_features=10240, out_features=2560, bias=True, w_bit=4, group_size=128)
#             (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
#   )
# )

# %%
print(f"Quantized model size:{calculate_model_size(quantized_AWQ_model):.2f}GB")
# 保存量化后的模型
quant_path = "smooth_W4A8_model"
quantized_AWQ_model.save_quantized(quant_path)
tokenizer.save_pretrained(quant_path)
# Out:
# Quantized model size:0.25GB
# ('smooth_W4A8_model/tokenizer_config.json',
#  'smooth_W4A8_model/special_tokens_map.json',
#  'smooth_W4A8_model/vocab.json',
#  'smooth_W4A8_model/merges.txt',
#  'smooth_W4A8_model/added_tokens.json',
#  'smooth_W4A8_model/tokenizer.json')

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=smooth_W4A8_model \
    --tasks hellaswag,lambada,piqa \
    --device cuda:0 \
    --batch_size 4
# Out:
# 2025-04-02 21:38:48.626477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743629928.648952   12888 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743629928.655787   12888 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-02:21:38:55 INFO     [__main__:422] Selected Tasks: ['hellaswag', 'lambada', 'piqa']
# 2025-04-02:21:38:55 INFO     [evaluator:180] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-04-02:21:38:55 INFO     [evaluator:218] Initializing hf model, with arguments: {'pretrained': 'smooth_W4A8_model'}
# 2025-04-02:21:38:55 INFO     [models.huggingface:136] Using device 'cuda:0'
# 2025-04-02:21:38:55 INFO     [models.huggingface:377] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# 2025-04-02:21:39:23 INFO     [api.task:426] Building contexts for piqa on rank 0...
# 100% 1838/1838 [00:01<00:00, 1122.39it/s]
# 2025-04-02:21:39:25 INFO     [api.task:426] Building contexts for lambada_openai on rank 0...
# 100% 5153/5153 [00:08<00:00, 604.99it/s]
# 2025-04-02:21:39:33 INFO     [api.task:426] Building contexts for lambada_standard on rank 0...
# 100% 5153/5153 [00:08<00:00, 603.29it/s]
# 2025-04-02:21:39:42 INFO     [api.task:426] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2423.57it/s]
# 2025-04-02:21:39:47 INFO     [evaluator:542] Running loglikelihood requests
# Running loglikelihood requests: 100% 54150/54150 [12:42<00:00, 70.99it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.60it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.27it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-04-02:21:53:25 INFO     [loggers.evaluation_tracker:272] Output path not provided, skipping saving results aggregated
# hf (pretrained=smooth_W4A8_model), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 4
# |     Tasks      |Version|Filter|n-shot|  Metric  |   |Value |   |Stderr|
# |----------------|------:|------|-----:|----------|---|-----:|---|-----:|
# |hellaswag       |      1|none  |     0|acc       |↑  |0.4587|±  |0.0050|
# |                |       |none  |     0|acc_norm  |↑  |0.6017|±  |0.0049|
# |lambada_openai  |      1|none  |     0|acc       |↑  |0.6472|±  |0.0067|
# |                |       |none  |     0|perplexity|↓  |5.0300|±  |0.1187|
# |lambada_standard|      1|none  |     0|acc       |↑  |0.5612|±  |0.0069|
# |                |       |none  |     0|perplexity|↓  |7.3413|±  |0.1964|
# |piqa            |      1|none  |     0|acc       |↑  |0.7416|±  |0.0102|
# |                |       |none  |     0|acc_norm  |↑  |0.7465|±  |0.0102|

# %% [markdown]
# #### 打印经过4bit权重量化（AWQ）且smooth后模型的精度

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=smooth_awq_quantized_model \
    --tasks hellaswag,lambada,piqa \
    --device cuda:0 \
    --batch_size 4
# Out:
# 2025-04-02 19:54:14.644216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743623654.666468   15421 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743623654.673125   15421 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-02:19:54:21 INFO     [__main__:422] Selected Tasks: ['hellaswag', 'lambada', 'piqa']
# 2025-04-02:19:54:21 INFO     [evaluator:180] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-04-02:19:54:21 INFO     [evaluator:218] Initializing hf model, with arguments: {'pretrained': 'smooth_awq_quantized_model'}
# 2025-04-02:19:54:21 INFO     [models.huggingface:136] Using device 'cuda:0'
# 2025-04-02:19:54:21 INFO     [models.huggingface:377] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# 2025-04-02:19:54:50 INFO     [api.task:426] Building contexts for piqa on rank 0...
# 100% 1838/1838 [00:01<00:00, 1108.34it/s]
# 2025-04-02:19:54:52 INFO     [api.task:426] Building contexts for lambada_openai on rank 0...
# 100% 5153/5153 [00:08<00:00, 589.87it/s]
# 2025-04-02:19:55:01 INFO     [api.task:426] Building contexts for lambada_standard on rank 0...
# 100% 5153/5153 [00:08<00:00, 595.64it/s]
# 2025-04-02:19:55:09 INFO     [api.task:426] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2408.24it/s]
# 2025-04-02:19:55:15 INFO     [evaluator:542] Running loglikelihood requests
# Running loglikelihood requests: 100% 54150/54150 [16:01<00:00, 56.30it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.58it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.79it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-04-02:20:12:12 INFO     [loggers.evaluation_tracker:272] Output path not provided, skipping saving results aggregated
# hf (pretrained=smooth_awq_quantized_model), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 4
# |     Tasks      |Version|Filter|n-shot|  Metric  |   |Value |   |Stderr|
# |----------------|------:|------|-----:|----------|---|-----:|---|-----:|
# |hellaswag       |      1|none  |     0|acc       |↑  |0.5013|±  |0.0050|
# |                |       |none  |     0|acc_norm  |↑  |0.6684|±  |0.0047|
# |lambada_openai  |      1|none  |     0|acc       |↑  |0.6769|±  |0.0065|
# |                |       |none  |     0|perplexity|↓  |4.2417|±  |0.0930|
# |lambada_standard|      1|none  |     0|acc       |↑  |0.6361|±  |0.0067|
# |                |       |none  |     0|perplexity|↓  |5.1539|±  |0.1208|
# |piqa            |      1|none  |     0|acc       |↑  |0.7655|±  |0.0099|
# |                |       |none  |     0|acc_norm  |↑  |0.7622|±  |0.0099|

# %% [markdown]
# #### 不进行smooth，直接进行4bit权重量化（AWQ）

# %%
original_model_path = "original_opt_2.7b"

awq_model_W4 = AutoAWQForCausalLM.from_pretrained(original_model_path)

tokenizer = AutoTokenizer.from_pretrained(original_model_path, trust_remote_code=True)

# 进行 AWQ 量化
quant_config = {"zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM"}
awq_model_W4.quantize(tokenizer, quant_config=quant_config)

# 保存量化后的模型
quant_path = "awq_quantized_model"
awq_model_W4.save_quantized(quant_path)
tokenizer.save_pretrained(quant_path)

print(f"Naive model AWQ without using smooth is saved at {quant_path}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# AWQ: 100%|██████████| 32/32 [06:49<00:00, 12.80s/it]
# Naive model AWQ without using smooth is saved at awq_quantized_model

# %%
import torch
import time

def measure_inference_time(model, inputs, num_runs=100):
    """
    测量模型的平均推理时间。

    参数:
    - model: 待测试的模型
    - inputs: 输入张量
    - num_runs: 运行次数，默认为 100

    返回:
    - 平均推理时间（秒）
    """
    # 确保模型和输入在同一设备上
    device = next(model.parameters()).device
    inputs = inputs.to(device)

    # 预热 (warm-up)，避免首次运行的时间偏差
    with torch.no_grad():
        _ = model(inputs)

    # 测量推理时间
    start_time = time.time()
    with torch.no_grad():
        for _ in range(num_runs):
            _ = model(inputs)
    end_time = time.time()

    # 计算平均推理时间
    avg_time = (end_time - start_time) / num_runs
    return avg_time

# %%
# 获取目标设备
device = next(quantized_AWQ_model.parameters()).device

# 将所有参数移动到目标设备
quantized_AWQ_model.to(device)

# 再次检查设备一致性
for name, param in quantized_AWQ_model.named_parameters():
    assert param.device == device, f"Parameter {name} is not on {device}"

for name, buffer in quantized_AWQ_model.named_buffers():
    assert buffer.device == device, f"Buffer {name} is not on {device}"


# 将模型的所有参数和缓冲区移动到目标设备
awq_model_W4.to(device)

# 再次检查设备一致性
for name, param in awq_model_W4.named_parameters():
    assert param.device == device, f"Parameter {name} is not on {device}"

for name, buffer in awq_model_W4.named_buffers():
    assert buffer.device == device, f"Buffer {name} is not on {device}"


# 假设词汇表大小为 30522，序列长度为 128
# 增加批量大小到 8
inputs = torch.randint(0, 30522, (8, 128), dtype=torch.long)

# %%
# 确保输入张量和模型在同一设备上
device = next(quantized_AWQ_model.parameters()).device  # 获取模型所在的设备
inputs = inputs.to(device)  # 将输入张量移动到该设备
print(f"Model device: {next(quantized_AWQ_model.parameters()).device}")
print(f"Inputs device: {inputs.device}")
# 示例调用
avg_time_w4a8 = measure_inference_time(quantized_AWQ_model, inputs)
avg_time_w4a16 = measure_inference_time(awq_model_W4, inputs)

print(f"W4A8 Average Inference Time: {avg_time_w4a8 * 1000:.2f} ms")
print(f"W4A16 Average Inference Time: {avg_time_w4a16 * 1000:.2f} ms")
# Out:
# Model device: cuda:0
# Inputs device: cuda:0
# W4A8 Average Inference Time: 62.92 ms
# W4A16 Average Inference Time: 62.57 ms

# %%
# 检查量化后的模型参数和缓冲区
for name, param in quantized_AWQ_model.named_parameters():
    print(f"Parameter: {name}, Dtype: {param.dtype}")

for name, buffer in quantized_AWQ_model.named_buffers():
    print(f"Buffer: {name}, Dtype: {buffer.dtype}")
# Out:
# Parameter: model.model.decoder.embed_tokens.weight, Dtype: torch.float16
# Parameter: model.model.decoder.embed_positions.weight, Dtype: torch.float16
# Parameter: model.model.decoder.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.0.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.0.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.0.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.0.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.1.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.1.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.1.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.1.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.2.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.2.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.2.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.2.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.3.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.3.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.3.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.3.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.4.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.4.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.4.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.4.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.5.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.5.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.5.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.5.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.6.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.6.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.6.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.6.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.7.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.7.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.7.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.7.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.8.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.8.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.8.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.8.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.9.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.9.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.9.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.9.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.10.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.10.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.10.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.10.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.11.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.11.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.11.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.11.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.12.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.12.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.12.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.12.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.13.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.13.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.13.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.13.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.14.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.14.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.14.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.14.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.15.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.15.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.15.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.15.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.16.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.16.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.16.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.16.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.17.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.17.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.17.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.17.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.18.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.18.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.18.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.18.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.19.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.19.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.19.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.19.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.20.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.20.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.20.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.20.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.21.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.21.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.21.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.21.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.22.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.22.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.22.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.22.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.23.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.23.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.23.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.23.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.24.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.24.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.24.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.24.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.25.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.25.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.25.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.25.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.26.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.26.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.26.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.26.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.27.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.27.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.27.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.27.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.28.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.28.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.28.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.28.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.29.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.29.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.29.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.29.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.30.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.30.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.30.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.30.final_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.31.self_attn_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.31.self_attn_layer_norm.bias, Dtype: torch.float16
# Parameter: model.model.decoder.layers.31.final_layer_norm.weight, Dtype: torch.float16
# Parameter: model.model.decoder.layers.31.final_layer_norm.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.0.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.0.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.1.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.1.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.2.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.2.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.3.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.3.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.4.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.4.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.5.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.5.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.6.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.6.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.7.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.7.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.8.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.8.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.9.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.9.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.10.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.10.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.11.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.11.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.12.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.12.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.13.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.13.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.14.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.14.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.15.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.15.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.16.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.16.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.17.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.17.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.18.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.18.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.19.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.19.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.19.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.19.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.19.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.19.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.19.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.19.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.19.self_attn.q_proj.qweight, Dtype: torch.int32
# ...
# Buffer: model.model.decoder.layers.23.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.23.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.23.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.23.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.23.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.23.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.23.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.23.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.23.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.23.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.23.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.24.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.24.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.25.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.25.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.26.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.26.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.27.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.27.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.28.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.28.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.29.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.29.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.30.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.30.fc2.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.k_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.k_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.k_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.k_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.v_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.v_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.v_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.v_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.q_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.q_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.q_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.q_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.out_proj.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.out_proj.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.self_attn.out_proj.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.self_attn.out_proj.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.fc1.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.fc1.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.fc1.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.fc1.bias, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.fc2.qweight, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.fc2.qzeros, Dtype: torch.int32
# Buffer: model.model.decoder.layers.31.fc2.scales, Dtype: torch.float16
# Buffer: model.model.decoder.layers.31.fc2.bias, Dtype: torch.float16

# %% [markdown]
# #### 打印不进行smooth操作，直接进行4bit AWQ模型的精度

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=awq_quantized_model \
    --tasks hellaswag,lambada,piqa \
    --device cuda:0 \
    --batch_size 4
# Out:
# 2025-04-02 19:35:31.361335: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743622531.382822   10532 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743622531.389338   10532 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-02:19:35:40 INFO     [__main__:422] Selected Tasks: ['hellaswag', 'lambada', 'piqa']
# 2025-04-02:19:35:40 INFO     [evaluator:180] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-04-02:19:35:40 INFO     [evaluator:218] Initializing hf model, with arguments: {'pretrained': 'awq_quantized_model'}
# 2025-04-02:19:35:40 INFO     [models.huggingface:136] Using device 'cuda:0'
# 2025-04-02:19:35:40 INFO     [models.huggingface:377] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# README.md: 100% 6.84k/6.84k [00:00<00:00, 27.2MB/s]
# hellaswag.py: 100% 4.36k/4.36k [00:00<00:00, 21.7MB/s]
# dataset_infos.json: 100% 2.53k/2.53k [00:00<00:00, 17.5MB/s]
# Downloading data: 100% 47.5M/47.5M [00:00<00:00, 290MB/s]
# Downloading data: 100% 11.8M/11.8M [00:00<00:00, 334MB/s]
# Downloading data: 100% 12.2M/12.2M [00:00<00:00, 335MB/s]
# Generating train split: 100% 39905/39905 [00:02<00:00, 14105.53 examples/s]
# Generating test split: 100% 10003/10003 [00:00<00:00, 14101.70 examples/s]
# Generating validation split: 100% 10042/10042 [00:00<00:00, 13987.04 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 5901.47 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6438.12 examples/s]
# README.md: 100% 7.32k/7.32k [00:00<00:00, 30.8MB/s]
# train-00000-of-00002.parquet: 100% 269M/269M [00:00<00:00, 453MB/s]
# train-00001-of-00002.parquet: 100% 281M/281M [00:00<00:00, 389MB/s]
# test-00000-of-00001.parquet: 100% 1.14M/1.14M [00:00<00:00, 133MB/s]
# validation-00000-of-00001.parquet: 100% 1.08M/1.08M [00:00<00:00, 319MB/s]
# Generating train split: 100% 2662/2662 [00:06<00:00, 437.32 examples/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 451508.25 examples/s]
# Generating validation split: 100% 4869/4869 [00:00<00:00, 533686.99 examples/s]
# README.md: 100% 4.99k/4.99k [00:00<00:00, 20.5MB/s]
# lambada_openai.py: 100% 4.82k/4.82k [00:00<00:00, 27.8MB/s]
# 0000.parquet: 100% 1.16M/1.16M [00:00<00:00, 105MB/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 529632.63 examples/s]
# piqa_train.parquet: 100% 2.64M/2.64M [00:00<00:00, 9.95MB/s]
# piqa_validation.parquet: 100% 300k/300k [00:00<00:00, 122MB/s]
# piqa_test.parquet: 100% 496k/496k [00:00<00:00, 104MB/s]
# Generating train split: 100% 16113/16113 [00:00<00:00, 992463.88 examples/s]
# Generating validation split: 100% 1838/1838 [00:00<00:00, 434243.83 examples/s]
# Generating test split: 100% 3084/3084 [00:00<00:00, 577775.31 examples/s]
# 2025-04-02:19:36:44 INFO     [api.task:426] Building contexts for piqa on rank 0...
# 100% 1838/1838 [00:01<00:00, 1118.90it/s]
# 2025-04-02:19:36:45 INFO     [api.task:426] Building contexts for lambada_openai on rank 0...
# 100% 5153/5153 [00:08<00:00, 599.61it/s]
# 2025-04-02:19:36:54 INFO     [api.task:426] Building contexts for lambada_standard on rank 0...
# 100% 5153/5153 [00:08<00:00, 596.07it/s]
# 2025-04-02:19:37:03 INFO     [api.task:426] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2409.48it/s]
# 2025-04-02:19:37:08 INFO     [evaluator:542] Running loglikelihood requests
# Running loglikelihood requests: 100% 54150/54150 [16:02<00:00, 56.27it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.68it/s]
# bootstrapping for stddev: perplexity
# 100% 100/100 [00:08<00:00, 11.47it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-04-02:19:54:07 INFO     [loggers.evaluation_tracker:272] Output path not provided, skipping saving results aggregated
# hf (pretrained=awq_quantized_model), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 4
# |     Tasks      |Version|Filter|n-shot|  Metric  |   |Value |   |Stderr|
# |----------------|------:|------|-----:|----------|---|-----:|---|-----:|
# |hellaswag       |      1|none  |     0|acc       |↑  |0.5019|±  |0.0050|
# |                |       |none  |     0|acc_norm  |↑  |0.6701|±  |0.0047|
# |lambada_openai  |      1|none  |     0|acc       |↑  |0.6755|±  |0.0065|
# |                |       |none  |     0|perplexity|↓  |4.2557|±  |0.0936|
# |lambada_standard|      1|none  |     0|acc       |↑  |0.6311|±  |0.0067|
# |                |       |none  |     0|perplexity|↓  |5.2392|±  |0.1240|
# |piqa            |      1|none  |     0|acc       |↑  |0.7671|±  |0.0099|
# |                |       |none  |     0|acc_norm  |↑  |0.7639|±  |0.0099|
